# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/synthetic_data.csv')
data
# Out:
#       record_id   age                sex  zip_code income_bracket  \
# 0       P000001  50.0               Male     10003      $50k–$75k
# 1       P000002  54.0               Male     10005      $25k–$50k
# 2       P000003  57.0             Female     60601          <$25k
# 3       P000004  51.0             Female     60601     $75k–$100k
# 4       P000005  24.0             Female     10004         >$100k
# ...         ...   ...                ...       ...            ...
# 99995   P099996  25.0               Male     90210      $25k–$50k
# 99996   P099997  50.0             Female     10002         >$100k
# 99997   P099998  50.0             Female     10002     $75k–$100k
# 99998   P099999  46.0               Male     10002      $50k–$75k
# 99999   P100000  38.0  Prefer not to say     10005          <$25k
#
#        education_level  has_chronic_condition   bmi  num_doctor_visits  \
# 0          High school                   True  21.8                8.0
# ...

# %%
data['zip_code'].value_counts()
# Out:
# zip_code
# 10005    10148
# 10001    10114
# 30301    10096
# 90210    10038
# 77001    10025
# 10002    10017
# 60601     9962
# 10003     9901
# 98101     9886
# 10004     9813
# Name: count, dtype: int64
