# %%
# %load_ext autoreload
# %autoreload 2

# %%
from modules.data_generator import make_data
from pathlib import Path
import pandas as pd
import sys

ROOT = Path('data_generator_example.ipynb').parent
sys.path.insert(0, str(ROOT))

# %%
data = make_data(
    n_med = 100, n_id = 50, n_overlap = 10, 
    config = 'default_config'
)
data
# Out:
#             address  age     sex conditions
# id_data  0      N4G   11  female        N/A
#          1      V4A   17  female        N/A
#          2      S0J   18  female        N/A
#          3      L3Y   19    male        N/A
#          4      H7M   17    male        N/A
# ...             ...  ...     ...        ...
# med_data 95     G0C   16    male        N/A
#          96     P2B   22  female        N/A
#          97     P0C    1    male        N/A
#          98     L4C    6    male        Q39
#          99     H4G   10    male        N/A
#
# [150 rows x 4 columns]

# %%
data.to_csv('data/temp.csv')
