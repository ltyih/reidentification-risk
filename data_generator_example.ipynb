# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from modules.data_generator import make_data
from pathlib import Path
import pandas as pd
import sys

ROOT = Path('data_generator_example.ipynb').parent
sys.path.insert(0, str(ROOT))

# %%
data = make_data(
    n_med = 5000, n_id = 0, n_overlap = 0, 
    config = 'default_config'
)
data = data.reset_index(drop=True)  # n_id = 387_000 (for copula and bayesian network)
data
# Out:
#      address  age                sex conditions  smoker  hbp
# 0        T3J    2               male        Q68     0.0  0.0
# 1        T1S   14             female        Q20     0.0  0.0
# 2        T3A   13               male        N/A     0.0  0.0
# 3        T3L   18             female        N/A     0.0  0.0
# 4        T3E   22  prefer not to say        N/A     0.0  0.0
# ...      ...  ...                ...        ...     ...  ...
# 4995     T3J    8             female        Q25     0.0  1.0
# 4996     T2V   19               male        N/A     0.0  0.0
# 4997     T3H   13               male        N/A     0.0  0.0
# 4998     T3G    0  prefer not to say        N/A     0.0  0.0
# 4999     T2L    6             female        Q45     0.0  0.0
#
# [5000 rows x 6 columns]

# %%
data.to_csv('data/temp.csv')
