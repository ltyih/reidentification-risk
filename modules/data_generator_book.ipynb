# %%
from config_fields import fields

# %%
fields[0]
# Out:
# Field(options='address', functions=['country', 'province', 'postcode'], choice=[<function sample_country at 0x000001CF2D06D9B0>, <function sample_province at 0x000001CF2CF2F740>, <function sample_postcode at 0x000001CF2BE2A770>], distribution='postcode', mean=None, std=None)
